# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.family'] = 'NanumGothic'

from sklearn.preprocessing import MinMaxScaler

import torch
import torch.nn as nn
from torch.autograd import Variable

import os, sys, random
from pathlib import Path
import glob

from tqdm import tqdm
from fastprogress import progress_bar

import warnings
warnings.filterwarnings(action='ignore')

# %%
CUR_DIR = Path.cwd()
DATA_DIR = CUR_DIR / 'data/preprocessed'
DATA_DIR
# Out:
# WindowsPath('C:/Users/안현준/풍년보험/data/preprocessed')

# %%
df = pd.read_csv(f'{str(DATA_DIR)}/summary.csv', encoding='utf-8')
df
# Out:
#           연월       감자      고구마    고추(화건)       깻잎    녹두(국산)            단감  \
# 0     2001_1  12191.0   8348.0  224565.0  16365.0  237774.0  14214.000000
# 1     2001_2  11558.0   9567.0  231208.0  12367.0  241875.0  16394.000000
# 2     2001_3  11885.0  13990.0  231962.0  10785.0  242000.0  21579.000000
# 3     2001_4  12133.0  14367.0  230333.0   8813.0  239833.0  21671.000000
# 4     2001_5  22625.0  13594.0  238083.0   7533.0  238000.0  23043.400000
# ..       ...      ...      ...       ...      ...       ...           ...
# 235   2020_8  32806.0  55765.0  692489.0  37550.0  463910.0  37260.285714
# 236   2020_9  35413.0  38834.0  871229.0  35653.0  498295.0  36936.142857
# 237  2020_10  34283.0  33565.0  812179.0  22075.0  542379.0  36612.000000
# 238  2020_11  35830.0  36263.0  824724.0  18950.0  586057.0  32381.000000
# 239  2020_12  32948.0  39418.0  794505.0  24227.0  637743.0  34417.000000
#
#      당근(무세척)      대파    들깨(국산)  ...      양배추       양파   오이(가시)      적상추  \
# 0     9313.0   855.0  171565.0  ...   3186.0  13734.0  20007.0   8772.0
# 1    10258.0   645.0  173458.0  ...   2747.0  14062.0  23917.0   8510.0
# 2    11277.0   669.0  183885.0  ...   2783.0  14422.0  19942.0   6909.0
# 3    13658.0   528.0  198375.0  ...   2574.0   8752.0  13074.0   5284.0
# 4    14900.0   803.0  199125.0  ...   2913.0   5150.0   9236.0   4828.0
# ..       ...     ...       ...  ...      ...      ...      ...      ...
# 235  45977.0  3081.0  488530.0  ...   9079.0  20492.0  32260.0  49308.0
# 236  70528.0  3178.0  527714.0  ...  13033.0  23636.0  35076.0  30401.0
# 237  66874.0  3019.0  571126.0  ...  17068.0  23749.0  15384.0  11982.0
# 238  42214.0  2982.0  606486.0  ...  12744.0  25540.0  20919.0  11180.0
# 239  26412.0  2400.0  639914.0  ...   7646.0  27366.0  26383.0  17630.0
#
#                참외   콩(흰콩국산)           토마토     팥(국산)        포도(캠벨)      풋고추
# 0    18722.666667  101957.0   8916.333333  147000.0   4490.857143  33783.0
# 1    35444.333333   95875.0  15831.666667  147875.0   6980.714286  58408.0
# 2    52166.000000   93885.0  22747.000000  147154.0   9470.571429  60646.0
# 3    39989.000000   91575.0  19756.000000  147000.0  11960.428571  24283.0
# 4    21800.000000   89142.0  13583.000000  147000.0  14450.285714  22025.0
# ..            ...       ...           ...       ...           ...      ...
# 235  49751.000000  184790.0  29638.000000  355400.0  23571.000000  51334.0
# 236  70438.000000  188171.0  50354.000000  365095.0  21720.000000  92749.0
# 237  64834.500000  189516.0  50018.000000  382979.0  20284.000000  63283.0
# 238  59231.000000  203514.0  35261.000000  453448.0  21071.333333  49019.0
# 239  53627.500000  216124.0  29929.000000  479800.0  21858.666667  30745.0
#
# [240 rows x 33 columns]

# %%
crops = df.columns[1:]
crops
# Out:
# Index(['감자', '고구마', '고추(화건)', '깻잎', '녹두(국산)', '단감', '당근(무세척)', '대파', '들깨(국산)',
#        '딸기', '무', '미나리', '방울토마토', '배(신고)', '배추', '백참깨(국산)', '복숭아(백도)',
#        '사과(후지)', '생강(국산)', '수박', '시금치', '애호박', '양배추', '양파', '오이(가시)', '적상추',
#        '참외', '콩(흰콩국산)', '토마토', '팥(국산)', '포도(캠벨)', '풋고추'],
#       dtype='object')

# %%
def sliding_windows(data, seq_length):
    x = []
    y = []

    for i in range(len(data) - seq_length - 1):
        _x = data[i:(i+seq_length)]
        _y = data[i+seq_length]
        x.append(_x)
        y.append(_y)

    return np.array(x),np.array(y)

# %%
class LSTM(nn.Module):

    def __init__(self, num_classes, input_size, hidden_size, num_layers):
        super(LSTM, self).__init__()
        
        self.num_classes = num_classes
        self.num_layers = num_layers
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.seq_length = seq_length
        
        self.lstm = nn.LSTM(input_size=input_size, hidden_size=hidden_size,
                            num_layers=num_layers, batch_first=True)
        
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        h_0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size)
        c_0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size)
        
        # Propagate input through LSTM
        ula, (h_out, _) = self.lstm(x, (h_0, c_0))
        
        h_out = h_out.view(-1, self.hidden_size)
        
        out = self.fc(h_out)
        
        return out

# %%
SEED = 42
def fix_seed(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    
fix_seed(SEED)

# %%
def plot_result(model, X, y, crop_name, path):
    model.eval()
    y_pred = model(X).data.numpy()
    y_true = y.data.numpy()
    
    y_pred = scaler.inverse_transform(y_pred)
    y_true = scaler.inverse_transform(y_true)
    
    plt.axvline(x=train_size, c='r', linestyle='--')
    plt.plot(y_true, label='true', color='black', alpha=0.7)
    plt.plot(y_pred, label='pred', color='#5392cd')
    plt.title(crop_name, fontsize=16)
    plt.legend(prop={'size': 14})
    plt.savefig(f'{path}/prices.png', dpi=300, bbox_inches='tight')
    plt.show()
    plt.clf()

# %%
def plot_loss(train_losses, valid_losses, crop_name, path):
    plt.plot(range(len(train_losses)), train_losses, label='train')
    plt.plot(range(len(valid_losses)), valid_losses, label='valid')
    title_ = f'Loss of {crop_name}'
    plt.title(title_, fontsize=16)
    plt.legend(prop={'size': 14})
    plt.savefig(f'{path}/{title_}.png', dpi=300, bbox_inches='tight')
    plt.clf()

# %%
def make_single_directory(path):
    os.makedirs(f'{path}', exist_ok=True)

# %%
def init_weights(m):
    for name, param in m.named_parameters():
        nn.init.uniform_(param.data, -0.08, 0.08)

# %%
scaler = MinMaxScaler(feature_range=(-1, 1))
seq_length = 12

num_epochs = 2000
learning_rate = 1e-2

input_size = 1
hidden_size = 100
num_layers = 1
num_classes = 1

fix_seed(SEED)

for i, crop in enumerate(progress_bar(crops)):
    print(f'Crop Name: {crop}')
    path = f'./results_test/{crop}'
    make_single_directory(path)
    
    # construct the data
    selected_data = scaler.fit_transform(df.iloc[:, i+1:i+2].values)
    X, y = sliding_windows(selected_data, seq_length)
    
    # train : test = 8 : 2
    train_size = int(len(y) * 0.8)
    test_size = len(y) - train_size
    
    X = torch.Tensor(np.array(X))
    y = torch.Tensor(np.array(y))

    X_train = torch.Tensor(np.array(X[:train_size]))
    y_train = torch.Tensor(np.array(y[:train_size]))

    X_test = torch.Tensor(np.array(X[train_size:]))
    y_test = torch.Tensor(np.array(y[train_size:]))

    # model and optimizer, scheduler
    model = LSTM(num_classes, input_size, hidden_size, num_layers)
    model.apply(init_weights)
    criterion = torch.nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer,  
                                                           patience=100,
                                                           factor =0.5 ,
                                                           min_lr=1e-8, 
                                                           eps=1e-08,
                                                           verbose=True)
    # train the model
    avg_train_loss, avg_valid_loss = 0.0, 0.0
    best_loss = float('inf')
    train_losses, valid_losses = [], []
    for epoch in progress_bar(range(1, num_epochs + 1)):
        # training mode
        model.train()
        outputs = model(X_train)
        optimizer.zero_grad()

        train_loss = criterion(outputs, y_train)
        train_losses.append(train_loss.item())
        avg_train_loss += train_loss.item()
        train_loss.backward()
        optimizer.step()
        
        # evaluation mode
        model.eval()
        valid = model(X_test)
        valid_loss = criterion(valid, y_test)
        valid_losses.append(valid_loss.item())
        avg_valid_loss += valid_loss.item()
        
        scheduler.step(valid_loss)
    
        # save the best model
        if (valid_loss.item() < best_loss) and epoch >= 500:
            torch.save(model, f'{path}/model_{crop}.pt')
            best_loss = valid_loss.item()
            #print(f'Save the best model at epoch {epoch}, best loss: {best_loss:.6f}')
                
        # print status
        if epoch % 100 == 0:
            avg_train_loss /= 100
            avg_valid_loss /= 100
            print(f'Epoch: {epoch:4d}, average train loss: {avg_train_loss:.6f}, average valid loss: {avg_valid_loss:.6f}')
            avg_train_loss, avg_valid_loss = 0.0, 0.0
        
    # load the model and infer
    best_model = torch.load(f'{path}/model_{crop}.pt')
    plot_result(best_model, X, y, crop, path)
    plot_loss(train_losses, valid_losses, crop, path)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='32' class='' max='32' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [32/32 1:10:16<00:00]
#     </div>
# Crop Name: 감자
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 02:13<00:00]
#     </div>
# Epoch:  100, average train loss: 0.115688, average valid loss: 0.189634
# Epoch   119: reducing learning rate of group 0 to 5.0000e-03.
# Epoch:  200, average train loss: 0.024845, average valid loss: 0.102955
# Epoch:  300, average train loss: 0.014778, average valid loss: 0.082203
# Epoch:  400, average train loss: 0.010830, average valid loss: 0.077201
# Epoch:  500, average train loss: 0.009013, average valid loss: 0.072681
# Epoch   527: reducing learning rate of group 0 to 2.5000e-03.
# Epoch:  600, average train loss: 0.007585, average valid loss: 0.078832
# Epoch   628: reducing learning rate of group 0 to 1.2500e-03.
# Epoch:  700, average train loss: 0.006808, average valid loss: 0.077694
# Epoch   729: reducing learning rate of group 0 to 6.2500e-04.
# Epoch:  800, average train loss: 0.006082, average valid loss: 0.076768
# Epoch   830: reducing learning rate of group 0 to 3.1250e-04.
# Epoch:  900, average train loss: 0.005814, average valid loss: 0.076472
# Epoch   931: reducing learning rate of group 0 to 1.5625e-04.
# Epoch: 1000, average train loss: 0.005659, average valid loss: 0.076292
# Epoch  1032: reducing learning rate of group 0 to 7.8125e-05.
# Epoch: 1100, average train loss: 0.005574, average valid loss: 0.076187
# Epoch  1133: reducing learning rate of group 0 to 3.9063e-05.
# Epoch: 1200, average train loss: 0.005528, average valid loss: 0.076129
# Epoch  1234: reducing learning rate of group 0 to 1.9531e-05.
# Epoch: 1300, average train loss: 0.005503, average valid loss: 0.076098
# Epoch  1335: reducing learning rate of group 0 to 9.7656e-06.
# Epoch: 1400, average train loss: 0.005490, average valid loss: 0.076082
# Epoch  1436: reducing learning rate of group 0 to 4.8828e-06.
# Epoch: 1500, average train loss: 0.005483, average valid loss: 0.076073
# Epoch  1537: reducing learning rate of group 0 to 2.4414e-06.
# Epoch: 1600, average train loss: 0.005479, average valid loss: 0.076068
# Epoch  1638: reducing learning rate of group 0 to 1.2207e-06.
# Epoch: 1700, average train loss: 0.005477, average valid loss: 0.076065
# Epoch  1739: reducing learning rate of group 0 to 6.1035e-07.
# Epoch: 1800, average train loss: 0.005476, average valid loss: 0.076064
# Epoch  1840: reducing learning rate of group 0 to 3.0518e-07.
# Epoch: 1900, average train loss: 0.005476, average valid loss: 0.076063
# Epoch  1941: reducing learning rate of group 0 to 1.5259e-07.
# Epoch: 2000, average train loss: 0.005475, average valid loss: 0.076063
# Crop Name: 고구마
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 02:06<00:00]
#     </div>
# Epoch:  100, average train loss: 0.101044, average valid loss: 0.182059
# Epoch:  200, average train loss: 0.014529, average valid loss: 0.035962
# Epoch:  300, average train loss: 0.007206, average valid loss: 0.029496
# Epoch   322: reducing learning rate of group 0 to 5.0000e-03.
# Epoch:  400, average train loss: 0.004294, average valid loss: 0.042994
# Epoch   423: reducing learning rate of group 0 to 2.5000e-03.
# Epoch:  500, average train loss: 0.002681, average valid loss: 0.051318
# Epoch   524: reducing learning rate of group 0 to 1.2500e-03.
# Epoch:  600, average train loss: 0.001696, average valid loss: 0.054474
# Epoch   625: reducing learning rate of group 0 to 6.2500e-04.
# Epoch:  700, average train loss: 0.001248, average valid loss: 0.055617
# Epoch   726: reducing learning rate of group 0 to 3.1250e-04.
# Epoch:  800, average train loss: 0.001049, average valid loss: 0.056984
# Epoch   827: reducing learning rate of group 0 to 1.5625e-04.
# Epoch:  900, average train loss: 0.000953, average valid loss: 0.057804
# Epoch   928: reducing learning rate of group 0 to 7.8125e-05.
# Epoch: 1000, average train loss: 0.000905, average valid loss: 0.058217
# Epoch  1029: reducing learning rate of group 0 to 3.9063e-05.
# Epoch: 1100, average train loss: 0.000879, average valid loss: 0.058428
# Epoch  1130: reducing learning rate of group 0 to 1.9531e-05.
# Epoch: 1200, average train loss: 0.000866, average valid loss: 0.058537
# Epoch  1231: reducing learning rate of group 0 to 9.7656e-06.
# Epoch: 1300, average train loss: 0.000859, average valid loss: 0.058595
# Epoch  1332: reducing learning rate of group 0 to 4.8828e-06.
# Epoch: 1400, average train loss: 0.000856, average valid loss: 0.058626
# Epoch  1433: reducing learning rate of group 0 to 2.4414e-06.
# Epoch: 1500, average train loss: 0.000854, average valid loss: 0.058642
# Epoch  1534: reducing learning rate of group 0 to 1.2207e-06.
# Epoch: 1600, average train loss: 0.000853, average valid loss: 0.058651
# Epoch  1635: reducing learning rate of group 0 to 6.1035e-07.
# Epoch: 1700, average train loss: 0.000852, average valid loss: 0.058656
# Epoch  1736: reducing learning rate of group 0 to 3.0518e-07.
# Epoch: 1800, average train loss: 0.000852, average valid loss: 0.058658
# Epoch  1837: reducing learning rate of group 0 to 1.5259e-07.
# Epoch: 1900, average train loss: 0.000852, average valid loss: 0.058660
# Epoch  1938: reducing learning rate of group 0 to 7.6294e-08.
# Epoch: 2000, average train loss: 0.000851, average valid loss: 0.058660
# Crop Name: 고추(화건)
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 02:11<00:00]
#     </div>
# Epoch:  100, average train loss: 0.020406, average valid loss: 0.082444
# Epoch:  200, average train loss: 0.005420, average valid loss: 0.030200
# Epoch:  300, average train loss: 0.004817, average valid loss: 0.026078
# Epoch   357: reducing learning rate of group 0 to 5.0000e-03.
# Epoch:  400, average train loss: 0.005351, average valid loss: 0.028140
# Epoch   458: reducing learning rate of group 0 to 2.5000e-03.
# Epoch:  500, average train loss: 0.004197, average valid loss: 0.025373
# Epoch   559: reducing learning rate of group 0 to 1.2500e-03.
# Epoch:  600, average train loss: 0.002654, average valid loss: 0.029857
# Epoch   660: reducing learning rate of group 0 to 6.2500e-04.
# Epoch:  700, average train loss: 0.001722, average valid loss: 0.032401
# Epoch   761: reducing learning rate of group 0 to 3.1250e-04.
# Epoch:  800, average train loss: 0.001684, average valid loss: 0.032983
# Epoch   862: reducing learning rate of group 0 to 1.5625e-04.
# Epoch:  900, average train loss: 0.001671, average valid loss: 0.033217
# Epoch   963: reducing learning rate of group 0 to 7.8125e-05.
# Epoch: 1000, average train loss: 0.001664, average valid loss: 0.033319
# Epoch  1064: reducing learning rate of group 0 to 3.9063e-05.
# Epoch: 1100, average train loss: 0.001661, average valid loss: 0.033369
# Epoch  1165: reducing learning rate of group 0 to 1.9531e-05.
# Epoch: 1200, average train loss: 0.001659, average valid loss: 0.033394
# Epoch  1266: reducing learning rate of group 0 to 9.7656e-06.
# Epoch: 1300, average train loss: 0.001658, average valid loss: 0.033407
# Epoch  1367: reducing learning rate of group 0 to 4.8828e-06.
# Epoch: 1400, average train loss: 0.001658, average valid loss: 0.033414
# Epoch  1468: reducing learning rate of group 0 to 2.4414e-06.
# Epoch: 1500, average train loss: 0.001657, average valid loss: 0.033418
# Epoch  1569: reducing learning rate of group 0 to 1.2207e-06.
# Epoch: 1600, average train loss: 0.001657, average valid loss: 0.033420
# Epoch  1670: reducing learning rate of group 0 to 6.1035e-07.
# Epoch: 1700, average train loss: 0.001657, average valid loss: 0.033421
# Epoch  1771: reducing learning rate of group 0 to 3.0518e-07.
# Epoch: 1800, average train loss: 0.001657, average valid loss: 0.033422
# Epoch  1872: reducing learning rate of group 0 to 1.5259e-07.
# Epoch: 1900, average train loss: 0.001657, average valid loss: 0.033422
# Epoch  1973: reducing learning rate of group 0 to 7.6294e-08.
# Epoch: 2000, average train loss: 0.001657, average valid loss: 0.033422
# Crop Name: 깻잎
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 02:07<00:00]
#     </div>
# Epoch:  100, average train loss: 0.057169, average valid loss: 0.135052
# Epoch   198: reducing learning rate of group 0 to 5.0000e-03.
# Epoch:  200, average train loss: 0.022920, average valid loss: 0.092633
# Epoch   299: reducing learning rate of group 0 to 2.5000e-03.
# Epoch:  300, average train loss: 0.005708, average valid loss: 0.095067
# Epoch   400: reducing learning rate of group 0 to 1.2500e-03.
# Epoch:  400, average train loss: 0.000815, average valid loss: 0.103333
# Epoch:  500, average train loss: 0.000160, average valid loss: 0.107826
# Epoch   501: reducing learning rate of group 0 to 6.2500e-04.
# Epoch:  600, average train loss: 0.000071, average valid loss: 0.109270
# Epoch   602: reducing learning rate of group 0 to 3.1250e-04.
# Epoch:  700, average train loss: 0.000046, average valid loss: 0.109932
# Epoch   703: reducing learning rate of group 0 to 1.5625e-04.
# Epoch:  800, average train loss: 0.000036, average valid loss: 0.110257
# Epoch   804: reducing learning rate of group 0 to 7.8125e-05.
# Epoch:  900, average train loss: 0.000032, average valid loss: 0.110420
# Epoch   905: reducing learning rate of group 0 to 3.9063e-05.
# Epoch: 1000, average train loss: 0.000029, average valid loss: 0.110505
# Epoch  1006: reducing learning rate of group 0 to 1.9531e-05.
# Epoch: 1100, average train loss: 0.000028, average valid loss: 0.110550
# Epoch  1107: reducing learning rate of group 0 to 9.7656e-06.
# Epoch: 1200, average train loss: 0.000027, average valid loss: 0.110574
# Epoch  1208: reducing learning rate of group 0 to 4.8828e-06.
# Epoch: 1300, average train loss: 0.000027, average valid loss: 0.110587
# Epoch  1309: reducing learning rate of group 0 to 2.4414e-06.
# Epoch: 1400, average train loss: 0.000027, average valid loss: 0.110593
# Epoch  1410: reducing learning rate of group 0 to 1.2207e-06.
# Epoch: 1500, average train loss: 0.000027, average valid loss: 0.110597
# Epoch  1511: reducing learning rate of group 0 to 6.1035e-07.
# Epoch: 1600, average train loss: 0.000027, average valid loss: 0.110599
# Epoch  1612: reducing learning rate of group 0 to 3.0518e-07.
# Epoch: 1700, average train loss: 0.000027, average valid loss: 0.110600
# Epoch  1713: reducing learning rate of group 0 to 1.5259e-07.
# Epoch: 1800, average train loss: 0.000027, average valid loss: 0.110600
# Epoch  1814: reducing learning rate of group 0 to 7.6294e-08.
# Epoch: 1900, average train loss: 0.000027, average valid loss: 0.110600
# Epoch  1915: reducing learning rate of group 0 to 3.8147e-08.
# Epoch: 2000, average train loss: 0.000027, average valid loss: 0.110600
# Crop Name: 녹두(국산)
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 02:17<00:00]
#     </div>
# Epoch:  100, average train loss: 0.021150, average valid loss: 0.018217
# Epoch:  200, average train loss: 0.004138, average valid loss: 0.003839
# Epoch:  300, average train loss: 0.004497, average valid loss: 0.003585
# Epoch:  400, average train loss: 0.003702, average valid loss: 0.003008
# Epoch   423: reducing learning rate of group 0 to 5.0000e-03.
# Epoch:  500, average train loss: 0.003420, average valid loss: 0.003896
# Epoch   524: reducing learning rate of group 0 to 2.5000e-03.
# Epoch:  600, average train loss: 0.003187, average valid loss: 0.004176
# Epoch   625: reducing learning rate of group 0 to 1.2500e-03.
# Epoch:  700, average train loss: 0.002953, average valid loss: 0.004124
# Epoch   726: reducing learning rate of group 0 to 6.2500e-04.
# Epoch:  800, average train loss: 0.002787, average valid loss: 0.003805
# Epoch   827: reducing learning rate of group 0 to 3.1250e-04.
# Epoch:  900, average train loss: 0.002641, average valid loss: 0.003471
# Epoch   928: reducing learning rate of group 0 to 1.5625e-04.
# Epoch: 1000, average train loss: 0.002516, average valid loss: 0.003217
# Epoch  1029: reducing learning rate of group 0 to 7.8125e-05.
# Epoch: 1100, average train loss: 0.002428, average valid loss: 0.003059
# Epoch  1130: reducing learning rate of group 0 to 3.9063e-05.
# Epoch: 1200, average train loss: 0.002374, average valid loss: 0.002972
# Epoch  1231: reducing learning rate of group 0 to 1.9531e-05.
# Epoch: 1300, average train loss: 0.002344, average valid loss: 0.002927
# Epoch  1332: reducing learning rate of group 0 to 9.7656e-06.
# Epoch: 1400, average train loss: 0.002328, average valid loss: 0.002903
# Epoch  1433: reducing learning rate of group 0 to 4.8828e-06.
# Epoch: 1500, average train loss: 0.002320, average valid loss: 0.002891
# Epoch  1534: reducing learning rate of group 0 to 2.4414e-06.
# Epoch: 1600, average train loss: 0.002316, average valid loss: 0.002885
# Epoch  1635: reducing learning rate of group 0 to 1.2207e-06.
# Epoch: 1700, average train loss: 0.002313, average valid loss: 0.002882
# Epoch  1736: reducing learning rate of group 0 to 6.1035e-07.
# Epoch: 1800, average train loss: 0.002312, average valid loss: 0.002880
# Epoch  1837: reducing learning rate of group 0 to 3.0518e-07.
# Epoch: 1900, average train loss: 0.002312, average valid loss: 0.002879
# Epoch  1938: reducing learning rate of group 0 to 1.5259e-07.
# Epoch: 2000, average train loss: 0.002311, average valid loss: 0.002879
# Crop Name: 단감
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 02:14<00:00]
#     </div>
# Epoch:  100, average train loss: 0.045606, average valid loss: 0.042906
# Epoch:  200, average train loss: 0.023785, average valid loss: 0.023376
# Epoch   249: reducing learning rate of group 0 to 5.0000e-03.
# Epoch:  300, average train loss: 0.008590, average valid loss: 0.024436
# Epoch   350: reducing learning rate of group 0 to 2.5000e-03.
# Epoch:  400, average train loss: 0.000858, average valid loss: 0.031574
# Epoch   451: reducing learning rate of group 0 to 1.2500e-03.
# Epoch:  500, average train loss: 0.000136, average valid loss: 0.032960
# Epoch   552: reducing learning rate of group 0 to 6.2500e-04.
# Epoch:  600, average train loss: 0.000060, average valid loss: 0.032429
# Epoch   653: reducing learning rate of group 0 to 3.1250e-04.
# Epoch:  700, average train loss: 0.000037, average valid loss: 0.032163
# Epoch   754: reducing learning rate of group 0 to 1.5625e-04.
# Epoch:  800, average train loss: 0.000029, average valid loss: 0.032051
# Epoch   855: reducing learning rate of group 0 to 7.8125e-05.
# Epoch:  900, average train loss: 0.000025, average valid loss: 0.032000
# Epoch   956: reducing learning rate of group 0 to 3.9063e-05.
# Epoch: 1000, average train loss: 0.000024, average valid loss: 0.031975
# Epoch  1057: reducing learning rate of group 0 to 1.9531e-05.
# Epoch: 1100, average train loss: 0.000023, average valid loss: 0.031962
# Epoch  1158: reducing learning rate of group 0 to 9.7656e-06.
# Epoch: 1200, average train loss: 0.000022, average valid loss: 0.031956
# Epoch  1259: reducing learning rate of group 0 to 4.8828e-06.
# Epoch: 1300, average train loss: 0.000022, average valid loss: 0.031952
# Epoch  1360: reducing learning rate of group 0 to 2.4414e-06.
# Epoch: 1400, average train loss: 0.000022, average valid loss: 0.031950
# Epoch  1461: reducing learning rate of group 0 to 1.2207e-06.
# Epoch: 1500, average train loss: 0.000022, average valid loss: 0.031949
# Epoch  1562: reducing learning rate of group 0 to 6.1035e-07.
# Epoch: 1600, average train loss: 0.000022, average valid loss: 0.031949
# Epoch  1663: reducing learning rate of group 0 to 3.0518e-07.
# Epoch: 1700, average train loss: 0.000022, average valid loss: 0.031948
# Epoch  1764: reducing learning rate of group 0 to 1.5259e-07.
# Epoch: 1800, average train loss: 0.000022, average valid loss: 0.031948
# Epoch  1865: reducing learning rate of group 0 to 7.6294e-08.
# Epoch: 1900, average train loss: 0.000022, average valid loss: 0.031948
# Epoch  1966: reducing learning rate of group 0 to 3.8147e-08.
# Epoch: 2000, average train loss: 0.000022, average valid loss: 0.031948
# Crop Name: 당근(무세척)
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 02:45<00:00]
#     </div>
# Epoch:  100, average train loss: 0.132423, average valid loss: 0.124068
# Epoch:  200, average train loss: 0.019802, average valid loss: 0.055303
# Epoch   229: reducing learning rate of group 0 to 5.0000e-03.
# Epoch:  300, average train loss: 0.011703, average valid loss: 0.062174
# Epoch   330: reducing learning rate of group 0 to 2.5000e-03.
# Epoch:  400, average train loss: 0.009106, average valid loss: 0.074467
# Epoch   431: reducing learning rate of group 0 to 1.2500e-03.
# Epoch:  500, average train loss: 0.008033, average valid loss: 0.075498
# Epoch   532: reducing learning rate of group 0 to 6.2500e-04.
# Epoch:  600, average train loss: 0.007304, average valid loss: 0.073807
# Epoch   633: reducing learning rate of group 0 to 3.1250e-04.
# Epoch:  700, average train loss: 0.006860, average valid loss: 0.072764
# Epoch   734: reducing learning rate of group 0 to 1.5625e-04.
# Epoch:  800, average train loss: 0.006597, average valid loss: 0.072174
# Epoch   835: reducing learning rate of group 0 to 7.8125e-05.
# Epoch:  900, average train loss: 0.006445, average valid loss: 0.071845
# Epoch   936: reducing learning rate of group 0 to 3.9063e-05.
# Epoch: 1000, average train loss: 0.006360, average valid loss: 0.071673
# Epoch  1037: reducing learning rate of group 0 to 1.9531e-05.
# Epoch: 1100, average train loss: 0.006313, average valid loss: 0.071585
# Epoch  1138: reducing learning rate of group 0 to 9.7656e-06.
# Epoch: 1200, average train loss: 0.006288, average valid loss: 0.071539
# Epoch  1239: reducing learning rate of group 0 to 4.8828e-06.
# Epoch: 1300, average train loss: 0.006274, average valid loss: 0.071516
# Epoch  1340: reducing learning rate of group 0 to 2.4414e-06.
# Epoch: 1400, average train loss: 0.006267, average valid loss: 0.071504
# Epoch  1441: reducing learning rate of group 0 to 1.2207e-06.
# Epoch: 1500, average train loss: 0.006263, average valid loss: 0.071498
# Epoch  1542: reducing learning rate of group 0 to 6.1035e-07.
# Epoch: 1600, average train loss: 0.006261, average valid loss: 0.071495
# Epoch  1643: reducing learning rate of group 0 to 3.0518e-07.
# Epoch: 1700, average train loss: 0.006260, average valid loss: 0.071494
# Epoch  1744: reducing learning rate of group 0 to 1.5259e-07.
# Epoch: 1800, average train loss: 0.006259, average valid loss: 0.071493
# Epoch  1845: reducing learning rate of group 0 to 7.6294e-08.
# Epoch: 1900, average train loss: 0.006259, average valid loss: 0.071492
# Epoch  1946: reducing learning rate of group 0 to 3.8147e-08.
# Epoch: 2000, average train loss: 0.006259, average valid loss: 0.071492
# Crop Name: 대파
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 02:14<00:00]
#     </div>
# Epoch:  100, average train loss: 0.114547, average valid loss: 0.113690
# Epoch:  200, average train loss: 0.033256, average valid loss: 0.043495
# Epoch:  300, average train loss: 0.026512, average valid loss: 0.040662
# Epoch   356: reducing learning rate of group 0 to 5.0000e-03.
# Epoch:  400, average train loss: 0.008856, average valid loss: 0.082575
# Epoch   457: reducing learning rate of group 0 to 2.5000e-03.
# Epoch:  500, average train loss: 0.001939, average valid loss: 0.115747
# Epoch   558: reducing learning rate of group 0 to 1.2500e-03.
# Epoch:  600, average train loss: 0.000867, average valid loss: 0.126128
# Epoch   659: reducing learning rate of group 0 to 6.2500e-04.
# Epoch:  700, average train loss: 0.000429, average valid loss: 0.132089
# Epoch   760: reducing learning rate of group 0 to 3.1250e-04.
# Epoch:  800, average train loss: 0.000271, average valid loss: 0.134811
# Epoch   861: reducing learning rate of group 0 to 1.5625e-04.
# Epoch:  900, average train loss: 0.000209, average valid loss: 0.136010
# Epoch   962: reducing learning rate of group 0 to 7.8125e-05.
# Epoch: 1000, average train loss: 0.000182, average valid loss: 0.136588
# Epoch  1063: reducing learning rate of group 0 to 3.9063e-05.
# Epoch: 1100, average train loss: 0.000168, average valid loss: 0.136882
# Epoch  1164: reducing learning rate of group 0 to 1.9531e-05.
# Epoch: 1200, average train loss: 0.000162, average valid loss: 0.137035
# Epoch  1265: reducing learning rate of group 0 to 9.7656e-06.
# Epoch: 1300, average train loss: 0.000158, average valid loss: 0.137117
# Epoch  1366: reducing learning rate of group 0 to 4.8828e-06.
# Epoch: 1400, average train loss: 0.000156, average valid loss: 0.137160
# Epoch  1467: reducing learning rate of group 0 to 2.4414e-06.
# Epoch: 1500, average train loss: 0.000155, average valid loss: 0.137184
# Epoch  1568: reducing learning rate of group 0 to 1.2207e-06.
# Epoch: 1600, average train loss: 0.000155, average valid loss: 0.137196
# Epoch  1669: reducing learning rate of group 0 to 6.1035e-07.
# Epoch: 1700, average train loss: 0.000154, average valid loss: 0.137202
# Epoch  1770: reducing learning rate of group 0 to 3.0518e-07.
# Epoch: 1800, average train loss: 0.000154, average valid loss: 0.137206
# Epoch  1871: reducing learning rate of group 0 to 1.5259e-07.
# Epoch: 1900, average train loss: 0.000154, average valid loss: 0.137208
# Epoch  1972: reducing learning rate of group 0 to 7.6294e-08.
# Epoch: 2000, average train loss: 0.000154, average valid loss: 0.137209
# Crop Name: 들깨(국산)
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 01:58<00:00]
#     </div>
# Epoch:  100, average train loss: 0.070075, average valid loss: 0.103759
# Epoch:  200, average train loss: 0.006828, average valid loss: 0.017642
# Epoch:  300, average train loss: 0.004258, average valid loss: 0.010767
# Epoch:  400, average train loss: 0.003957, average valid loss: 0.008620
# Epoch:  500, average train loss: 0.003035, average valid loss: 0.006611
# Epoch   574: reducing learning rate of group 0 to 5.0000e-03.
# Epoch:  600, average train loss: 0.002567, average valid loss: 0.010326
# Epoch   675: reducing learning rate of group 0 to 2.5000e-03.
# Epoch:  700, average train loss: 0.002414, average valid loss: 0.013620
# Epoch   776: reducing learning rate of group 0 to 1.2500e-03.
# Epoch:  800, average train loss: 0.002354, average valid loss: 0.014345
# Epoch   877: reducing learning rate of group 0 to 6.2500e-04.
# Epoch:  900, average train loss: 0.002324, average valid loss: 0.014593
# Epoch   978: reducing learning rate of group 0 to 3.1250e-04.
# Epoch: 1000, average train loss: 0.002307, average valid loss: 0.014738
# Epoch  1079: reducing learning rate of group 0 to 1.5625e-04.
# Epoch: 1100, average train loss: 0.002298, average valid loss: 0.014834
# Epoch  1180: reducing learning rate of group 0 to 7.8125e-05.
# Epoch: 1200, average train loss: 0.002293, average valid loss: 0.014895
# Epoch  1281: reducing learning rate of group 0 to 3.9063e-05.
# Epoch: 1300, average train loss: 0.002290, average valid loss: 0.014930
# Epoch  1382: reducing learning rate of group 0 to 1.9531e-05.
# Epoch: 1400, average train loss: 0.002288, average valid loss: 0.014950
# Epoch  1483: reducing learning rate of group 0 to 9.7656e-06.
# Epoch: 1500, average train loss: 0.002288, average valid loss: 0.014961
# Epoch  1584: reducing learning rate of group 0 to 4.8828e-06.
# Epoch: 1600, average train loss: 0.002287, average valid loss: 0.014968
# Epoch  1685: reducing learning rate of group 0 to 2.4414e-06.
# Epoch: 1700, average train loss: 0.002287, average valid loss: 0.014971
# Epoch  1786: reducing learning rate of group 0 to 1.2207e-06.
# Epoch: 1800, average train loss: 0.002287, average valid loss: 0.014973
# Epoch  1887: reducing learning rate of group 0 to 6.1035e-07.
# Epoch: 1900, average train loss: 0.002287, average valid loss: 0.014973
# Epoch  1988: reducing learning rate of group 0 to 3.0518e-07.
# Epoch: 2000, average train loss: 0.002287, average valid loss: 0.014974
# Crop Name: 딸기
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 02:04<00:00]
#     </div>
# Epoch:  100, average train loss: 0.033480, average valid loss: 0.056083
# Epoch:  200, average train loss: 0.007541, average valid loss: 0.024448
# Epoch   255: reducing learning rate of group 0 to 5.0000e-03.
# Epoch:  300, average train loss: 0.003081, average valid loss: 0.025044
# Epoch:  400, average train loss: 0.001206, average valid loss: 0.020401
# Epoch   432: reducing learning rate of group 0 to 2.5000e-03.
# Epoch:  500, average train loss: 0.000556, average valid loss: 0.021681
# Epoch   533: reducing learning rate of group 0 to 1.2500e-03.
# Epoch:  600, average train loss: 0.000211, average valid loss: 0.022485
# Epoch   634: reducing learning rate of group 0 to 6.2500e-04.
# Epoch:  700, average train loss: 0.000136, average valid loss: 0.022622
# Epoch   735: reducing learning rate of group 0 to 3.1250e-04.
# Epoch:  800, average train loss: 0.000111, average valid loss: 0.022830
# Epoch   836: reducing learning rate of group 0 to 1.5625e-04.
# Epoch:  900, average train loss: 0.000101, average valid loss: 0.022938
# Epoch   937: reducing learning rate of group 0 to 7.8125e-05.
# Epoch: 1000, average train loss: 0.000096, average valid loss: 0.022988
# Epoch  1038: reducing learning rate of group 0 to 3.9063e-05.
# Epoch: 1100, average train loss: 0.000094, average valid loss: 0.023013
# Epoch  1139: reducing learning rate of group 0 to 1.9531e-05.
# Epoch: 1200, average train loss: 0.000093, average valid loss: 0.023025
# Epoch  1240: reducing learning rate of group 0 to 9.7656e-06.
# Epoch: 1300, average train loss: 0.000092, average valid loss: 0.023032
# Epoch  1341: reducing learning rate of group 0 to 4.8828e-06.
# Epoch: 1400, average train loss: 0.000092, average valid loss: 0.023035
# Epoch  1442: reducing learning rate of group 0 to 2.4414e-06.
# Epoch: 1500, average train loss: 0.000092, average valid loss: 0.023037
# Epoch  1543: reducing learning rate of group 0 to 1.2207e-06.
# Epoch: 1600, average train loss: 0.000092, average valid loss: 0.023038
# Epoch  1644: reducing learning rate of group 0 to 6.1035e-07.
# Epoch: 1700, average train loss: 0.000092, average valid loss: 0.023039
# Epoch  1745: reducing learning rate of group 0 to 3.0518e-07.
# Epoch: 1800, average train loss: 0.000092, average valid loss: 0.023039
# Epoch  1846: reducing learning rate of group 0 to 1.5259e-07.
# Epoch: 1900, average train loss: 0.000092, average valid loss: 0.023039
# Epoch  1947: reducing learning rate of group 0 to 7.6294e-08.
# Epoch: 2000, average train loss: 0.000092, average valid loss: 0.023039
# Crop Name: 무
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 02:08<00:00]
#     </div>
# Epoch:  100, average train loss: 0.145514, average valid loss: 0.167925
# Epoch:  200, average train loss: 0.037240, average valid loss: 0.069280
# Epoch   271: reducing learning rate of group 0 to 5.0000e-03.
# Epoch:  300, average train loss: 0.014438, average valid loss: 0.101634
# Epoch   372: reducing learning rate of group 0 to 2.5000e-03.
# Epoch:  400, average train loss: 0.002430, average valid loss: 0.161872
# Epoch   473: reducing learning rate of group 0 to 1.2500e-03.
# Epoch:  500, average train loss: 0.000584, average valid loss: 0.179269
# Epoch   574: reducing learning rate of group 0 to 6.2500e-04.
# Epoch:  600, average train loss: 0.000289, average valid loss: 0.183565
# Epoch   675: reducing learning rate of group 0 to 3.1250e-04.
# Epoch:  700, average train loss: 0.000199, average valid loss: 0.184478
# Epoch   776: reducing learning rate of group 0 to 1.5625e-04.
# Epoch:  800, average train loss: 0.000164, average valid loss: 0.184762
# Epoch   877: reducing learning rate of group 0 to 7.8125e-05.
# Epoch:  900, average train loss: 0.000148, average valid loss: 0.184876
# Epoch   978: reducing learning rate of group 0 to 3.9063e-05.
# Epoch: 1000, average train loss: 0.000141, average valid loss: 0.184928
# Epoch  1079: reducing learning rate of group 0 to 1.9531e-05.
# Epoch: 1100, average train loss: 0.000137, average valid loss: 0.184954
# Epoch  1180: reducing learning rate of group 0 to 9.7656e-06.
# Epoch: 1200, average train loss: 0.000135, average valid loss: 0.184968
# Epoch  1281: reducing learning rate of group 0 to 4.8828e-06.
# Epoch: 1300, average train loss: 0.000133, average valid loss: 0.184975
# Epoch  1382: reducing learning rate of group 0 to 2.4414e-06.
# Epoch: 1400, average train loss: 0.000133, average valid loss: 0.184979
# Epoch  1483: reducing learning rate of group 0 to 1.2207e-06.
# Epoch: 1500, average train loss: 0.000133, average valid loss: 0.184981
# Epoch  1584: reducing learning rate of group 0 to 6.1035e-07.
# Epoch: 1600, average train loss: 0.000132, average valid loss: 0.184982
# Epoch  1685: reducing learning rate of group 0 to 3.0518e-07.
# Epoch: 1700, average train loss: 0.000132, average valid loss: 0.184982
# Epoch  1786: reducing learning rate of group 0 to 1.5259e-07.
# Epoch: 1800, average train loss: 0.000132, average valid loss: 0.184982
# Epoch  1887: reducing learning rate of group 0 to 7.6294e-08.
# Epoch: 1900, average train loss: 0.000132, average valid loss: 0.184981
# Epoch  1988: reducing learning rate of group 0 to 3.8147e-08.
# Epoch: 2000, average train loss: 0.000132, average valid loss: 0.184981
# Crop Name: 미나리
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 02:05<00:00]
#     </div>
# Epoch:  100, average train loss: 0.103021, average valid loss: 0.202166
# Epoch   106: reducing learning rate of group 0 to 5.0000e-03.
# Epoch:  200, average train loss: 0.028427, average valid loss: 0.103935
# Epoch:  300, average train loss: 0.014954, average valid loss: 0.078456
# Epoch:  400, average train loss: 0.013676, average valid loss: 0.078164
# Epoch   431: reducing learning rate of group 0 to 2.5000e-03.
# Epoch:  500, average train loss: 0.012719, average valid loss: 0.081960
# Epoch   532: reducing learning rate of group 0 to 1.2500e-03.
# Epoch:  600, average train loss: 0.012331, average valid loss: 0.081061
# Epoch   633: reducing learning rate of group 0 to 6.2500e-04.
# Epoch:  700, average train loss: 0.011842, average valid loss: 0.079530
# Epoch   734: reducing learning rate of group 0 to 3.1250e-04.
# Epoch:  800, average train loss: 0.011323, average valid loss: 0.079092
# Epoch   835: reducing learning rate of group 0 to 1.5625e-04.
# Epoch:  900, average train loss: 0.011012, average valid loss: 0.078778
# Epoch   936: reducing learning rate of group 0 to 7.8125e-05.
# Epoch: 1000, average train loss: 0.010825, average valid loss: 0.078379
# Epoch  1037: reducing learning rate of group 0 to 3.9063e-05.
# Epoch: 1100, average train loss: 0.010722, average valid loss: 0.078256
# Epoch  1138: reducing learning rate of group 0 to 1.9531e-05.
# Epoch: 1200, average train loss: 0.010668, average valid loss: 0.078255
# Epoch  1239: reducing learning rate of group 0 to 9.7656e-06.
# Epoch: 1300, average train loss: 0.010639, average valid loss: 0.078273
# Epoch  1340: reducing learning rate of group 0 to 4.8828e-06.
# Epoch: 1400, average train loss: 0.010624, average valid loss: 0.078288
# Epoch  1441: reducing learning rate of group 0 to 2.4414e-06.
# Epoch: 1500, average train loss: 0.010616, average valid loss: 0.078298
# Epoch  1542: reducing learning rate of group 0 to 1.2207e-06.
# Epoch: 1600, average train loss: 0.010612, average valid loss: 0.078303
# Epoch  1643: reducing learning rate of group 0 to 6.1035e-07.
# Epoch: 1700, average train loss: 0.010610, average valid loss: 0.078306
# Epoch  1744: reducing learning rate of group 0 to 3.0518e-07.
# Epoch: 1800, average train loss: 0.010609, average valid loss: 0.078307
# Epoch  1845: reducing learning rate of group 0 to 1.5259e-07.
# Epoch: 1900, average train loss: 0.010608, average valid loss: 0.078308
# Epoch  1946: reducing learning rate of group 0 to 7.6294e-08.
# Epoch: 2000, average train loss: 0.010608, average valid loss: 0.078309
# Crop Name: 방울토마토
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 02:05<00:00]
#     </div>
# Epoch:  100, average train loss: 0.088910, average valid loss: 0.129399
# Epoch   186: reducing learning rate of group 0 to 5.0000e-03.
# Epoch:  200, average train loss: 0.020734, average valid loss: 0.131686
# Epoch   287: reducing learning rate of group 0 to 2.5000e-03.
# Epoch:  300, average train loss: 0.000261, average valid loss: 0.150644
# Epoch   388: reducing learning rate of group 0 to 1.2500e-03.
# Epoch:  400, average train loss: 0.000003, average valid loss: 0.154460
# Epoch   489: reducing learning rate of group 0 to 6.2500e-04.
# Epoch:  500, average train loss: 0.000000, average valid loss: 0.154809
# Epoch   590: reducing learning rate of group 0 to 3.1250e-04.
# Epoch:  600, average train loss: 0.000000, average valid loss: 0.154923
# Epoch   691: reducing learning rate of group 0 to 1.5625e-04.
# Epoch:  700, average train loss: 0.000000, average valid loss: 0.154974
# Epoch   792: reducing learning rate of group 0 to 7.8125e-05.
# Epoch:  800, average train loss: 0.000000, average valid loss: 0.154999
# Epoch   893: reducing learning rate of group 0 to 3.9063e-05.
# Epoch:  900, average train loss: 0.000000, average valid loss: 0.155011
# Epoch   994: reducing learning rate of group 0 to 1.9531e-05.
# Epoch: 1000, average train loss: 0.000000, average valid loss: 0.155018
# Epoch  1095: reducing learning rate of group 0 to 9.7656e-06.
# Epoch: 1100, average train loss: 0.000000, average valid loss: 0.155022
# Epoch  1196: reducing learning rate of group 0 to 4.8828e-06.
# Epoch: 1200, average train loss: 0.000000, average valid loss: 0.155023
# Epoch  1297: reducing learning rate of group 0 to 2.4414e-06.
# Epoch: 1300, average train loss: 0.000000, average valid loss: 0.155024
# Epoch  1398: reducing learning rate of group 0 to 1.2207e-06.
# Epoch: 1400, average train loss: 0.000000, average valid loss: 0.155025
# Epoch  1499: reducing learning rate of group 0 to 6.1035e-07.
# Epoch: 1500, average train loss: 0.000000, average valid loss: 0.155025
# Epoch  1600: reducing learning rate of group 0 to 3.0518e-07.
# Epoch: 1600, average train loss: 0.000000, average valid loss: 0.155025
# Epoch: 1700, average train loss: 0.000000, average valid loss: 0.155025
# Epoch  1701: reducing learning rate of group 0 to 1.5259e-07.
# Epoch: 1800, average train loss: 0.000000, average valid loss: 0.155025
# Epoch  1802: reducing learning rate of group 0 to 7.6294e-08.
# Epoch: 1900, average train loss: 0.000000, average valid loss: 0.155025
# Epoch  1903: reducing learning rate of group 0 to 3.8147e-08.
# Epoch: 2000, average train loss: 0.000000, average valid loss: 0.155025
# Crop Name: 배(신고)
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 02:06<00:00]
#     </div>
# Epoch:  100, average train loss: 0.048448, average valid loss: 0.046482
# Epoch   143: reducing learning rate of group 0 to 5.0000e-03.
# Epoch:  200, average train loss: 0.008829, average valid loss: 0.048586
# Epoch   244: reducing learning rate of group 0 to 2.5000e-03.
# Epoch:  300, average train loss: 0.003538, average valid loss: 0.044691
# Epoch   345: reducing learning rate of group 0 to 1.2500e-03.
# Epoch:  400, average train loss: 0.001476, average valid loss: 0.044229
# Epoch   446: reducing learning rate of group 0 to 6.2500e-04.
# Epoch:  500, average train loss: 0.000393, average valid loss: 0.045995
# Epoch   547: reducing learning rate of group 0 to 3.1250e-04.
# Epoch:  600, average train loss: 0.000236, average valid loss: 0.047577
# Epoch   648: reducing learning rate of group 0 to 1.5625e-04.
# Epoch:  700, average train loss: 0.000190, average valid loss: 0.048272
# Epoch   749: reducing learning rate of group 0 to 7.8125e-05.
# Epoch:  800, average train loss: 0.000173, average valid loss: 0.048574
# Epoch   850: reducing learning rate of group 0 to 3.9063e-05.
# Epoch:  900, average train loss: 0.000165, average valid loss: 0.048715
# Epoch   951: reducing learning rate of group 0 to 1.9531e-05.
# Epoch: 1000, average train loss: 0.000161, average valid loss: 0.048787
# Epoch  1052: reducing learning rate of group 0 to 9.7656e-06.
# Epoch: 1100, average train loss: 0.000159, average valid loss: 0.048823
# Epoch  1153: reducing learning rate of group 0 to 4.8828e-06.
# Epoch: 1200, average train loss: 0.000158, average valid loss: 0.048843
# Epoch  1254: reducing learning rate of group 0 to 2.4414e-06.
# Epoch: 1300, average train loss: 0.000157, average valid loss: 0.048853
# Epoch  1355: reducing learning rate of group 0 to 1.2207e-06.
# Epoch: 1400, average train loss: 0.000157, average valid loss: 0.048859
# Epoch  1456: reducing learning rate of group 0 to 6.1035e-07.
# Epoch: 1500, average train loss: 0.000157, average valid loss: 0.048862
# Epoch  1557: reducing learning rate of group 0 to 3.0518e-07.
# Epoch: 1600, average train loss: 0.000157, average valid loss: 0.048863
# Epoch  1658: reducing learning rate of group 0 to 1.5259e-07.
# Epoch: 1700, average train loss: 0.000157, average valid loss: 0.048864
# Epoch  1759: reducing learning rate of group 0 to 7.6294e-08.
# Epoch: 1800, average train loss: 0.000157, average valid loss: 0.048864
# Epoch  1860: reducing learning rate of group 0 to 3.8147e-08.
# Epoch: 1900, average train loss: 0.000157, average valid loss: 0.048864
# Epoch  1961: reducing learning rate of group 0 to 1.9073e-08.
# Epoch: 2000, average train loss: 0.000157, average valid loss: 0.048864
# Crop Name: 배추
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 02:14<00:00]
#     </div>
# Epoch:  100, average train loss: 0.116772, average valid loss: 0.197171
# Epoch:  200, average train loss: 0.033154, average valid loss: 0.083765
# Epoch   267: reducing learning rate of group 0 to 5.0000e-03.
# Epoch:  300, average train loss: 0.016629, average valid loss: 0.112087
# Epoch   368: reducing learning rate of group 0 to 2.5000e-03.
# Epoch:  400, average train loss: 0.010637, average valid loss: 0.104606
# Epoch   469: reducing learning rate of group 0 to 1.2500e-03.
# Epoch:  500, average train loss: 0.006573, average valid loss: 0.105743
# Epoch   570: reducing learning rate of group 0 to 6.2500e-04.
# Epoch:  600, average train loss: 0.003839, average valid loss: 0.114304
# Epoch   671: reducing learning rate of group 0 to 3.1250e-04.
# Epoch:  700, average train loss: 0.002598, average valid loss: 0.119519
# Epoch   772: reducing learning rate of group 0 to 1.5625e-04.
# Epoch:  800, average train loss: 0.002056, average valid loss: 0.121617
# Epoch   873: reducing learning rate of group 0 to 7.8125e-05.
# Epoch:  900, average train loss: 0.001860, average valid loss: 0.122468
# Epoch   974: reducing learning rate of group 0 to 3.9063e-05.
# Epoch: 1000, average train loss: 0.001768, average valid loss: 0.122798
# Epoch  1075: reducing learning rate of group 0 to 1.9531e-05.
# Epoch: 1100, average train loss: 0.001721, average valid loss: 0.122948
# Epoch  1176: reducing learning rate of group 0 to 9.7656e-06.
# Epoch: 1200, average train loss: 0.001697, average valid loss: 0.123021
# Epoch  1277: reducing learning rate of group 0 to 4.8828e-06.
# Epoch: 1300, average train loss: 0.001684, average valid loss: 0.123059
# Epoch  1378: reducing learning rate of group 0 to 2.4414e-06.
# Epoch: 1400, average train loss: 0.001678, average valid loss: 0.123078
# Epoch  1479: reducing learning rate of group 0 to 1.2207e-06.
# Epoch: 1500, average train loss: 0.001674, average valid loss: 0.123089
# Epoch  1580: reducing learning rate of group 0 to 6.1035e-07.
# ...
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 02:07<00:00]
#     </div>
# Epoch:  100, average train loss: 0.027167, average valid loss: 0.007617
# Epoch   198: reducing learning rate of group 0 to 5.0000e-03.
# Epoch:  200, average train loss: 0.006535, average valid loss: 0.001442
# Epoch   299: reducing learning rate of group 0 to 2.5000e-03.
# Epoch:  300, average train loss: 0.004754, average valid loss: 0.001608
# Epoch   400: reducing learning rate of group 0 to 1.2500e-03.
# Epoch:  400, average train loss: 0.002999, average valid loss: 0.001553
# Epoch:  500, average train loss: 0.001957, average valid loss: 0.001964
# Epoch   501: reducing learning rate of group 0 to 6.2500e-04.
# Epoch:  600, average train loss: 0.001636, average valid loss: 0.002457
# Epoch   602: reducing learning rate of group 0 to 3.1250e-04.
# Epoch:  700, average train loss: 0.001534, average valid loss: 0.002733
# Epoch   703: reducing learning rate of group 0 to 1.5625e-04.
# Epoch:  800, average train loss: 0.001490, average valid loss: 0.002853
# Epoch   804: reducing learning rate of group 0 to 7.8125e-05.
# Epoch:  900, average train loss: 0.001468, average valid loss: 0.002911
# Epoch   905: reducing learning rate of group 0 to 3.9063e-05.
# Epoch: 1000, average train loss: 0.001456, average valid loss: 0.002939
# Epoch  1006: reducing learning rate of group 0 to 1.9531e-05.
# Epoch: 1100, average train loss: 0.001449, average valid loss: 0.002954
# Epoch  1107: reducing learning rate of group 0 to 9.7656e-06.
# Epoch: 1200, average train loss: 0.001446, average valid loss: 0.002962
# Epoch  1208: reducing learning rate of group 0 to 4.8828e-06.
# Epoch: 1300, average train loss: 0.001444, average valid loss: 0.002966
# Epoch  1309: reducing learning rate of group 0 to 2.4414e-06.
# Epoch: 1400, average train loss: 0.001443, average valid loss: 0.002969
# Epoch  1410: reducing learning rate of group 0 to 1.2207e-06.
# Epoch: 1500, average train loss: 0.001442, average valid loss: 0.002970
# Epoch  1511: reducing learning rate of group 0 to 6.1035e-07.
# Epoch: 1600, average train loss: 0.001442, average valid loss: 0.002970
# Epoch  1612: reducing learning rate of group 0 to 3.0518e-07.
# Epoch: 1700, average train loss: 0.001442, average valid loss: 0.002971
# Epoch  1713: reducing learning rate of group 0 to 1.5259e-07.
# Epoch: 1800, average train loss: 0.001442, average valid loss: 0.002971
# Epoch  1814: reducing learning rate of group 0 to 7.6294e-08.
# Epoch: 1900, average train loss: 0.001442, average valid loss: 0.002971
# Epoch  1915: reducing learning rate of group 0 to 3.8147e-08.
# Epoch: 2000, average train loss: 0.001442, average valid loss: 0.002971
# Crop Name: 토마토
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 02:09<00:00]
#     </div>
# Epoch:  100, average train loss: 0.051948, average valid loss: 0.095849
# Epoch   166: reducing learning rate of group 0 to 5.0000e-03.
# Epoch:  200, average train loss: 0.009878, average valid loss: 0.152455
# Epoch   267: reducing learning rate of group 0 to 2.5000e-03.
# Epoch:  300, average train loss: 0.000158, average valid loss: 0.195414
# Epoch   368: reducing learning rate of group 0 to 1.2500e-03.
# Epoch:  400, average train loss: 0.000007, average valid loss: 0.202158
# Epoch   469: reducing learning rate of group 0 to 6.2500e-04.
# Epoch:  500, average train loss: 0.000001, average valid loss: 0.203853
# Epoch   570: reducing learning rate of group 0 to 3.1250e-04.
# Epoch:  600, average train loss: 0.000001, average valid loss: 0.204425
# Epoch   671: reducing learning rate of group 0 to 1.5625e-04.
# Epoch:  700, average train loss: 0.000000, average valid loss: 0.204658
# Epoch   772: reducing learning rate of group 0 to 7.8125e-05.
# Epoch:  800, average train loss: 0.000000, average valid loss: 0.204766
# Epoch   873: reducing learning rate of group 0 to 3.9063e-05.
# Epoch:  900, average train loss: 0.000000, average valid loss: 0.204820
# Epoch   974: reducing learning rate of group 0 to 1.9531e-05.
# Epoch: 1000, average train loss: 0.000000, average valid loss: 0.204847
# Epoch  1075: reducing learning rate of group 0 to 9.7656e-06.
# Epoch: 1100, average train loss: 0.000000, average valid loss: 0.204862
# Epoch  1176: reducing learning rate of group 0 to 4.8828e-06.
# Epoch: 1200, average train loss: 0.000000, average valid loss: 0.204870
# Epoch  1277: reducing learning rate of group 0 to 2.4414e-06.
# Epoch: 1300, average train loss: 0.000000, average valid loss: 0.204874
# Epoch  1378: reducing learning rate of group 0 to 1.2207e-06.
# Epoch: 1400, average train loss: 0.000000, average valid loss: 0.204875
# Epoch  1479: reducing learning rate of group 0 to 6.1035e-07.
# Epoch: 1500, average train loss: 0.000000, average valid loss: 0.204876
# Epoch  1580: reducing learning rate of group 0 to 3.0518e-07.
# Epoch: 1600, average train loss: 0.000000, average valid loss: 0.204876
# Epoch  1681: reducing learning rate of group 0 to 1.5259e-07.
# Epoch: 1700, average train loss: 0.000000, average valid loss: 0.204876
# Epoch  1782: reducing learning rate of group 0 to 7.6294e-08.
# Epoch: 1800, average train loss: 0.000000, average valid loss: 0.204876
# Epoch  1883: reducing learning rate of group 0 to 3.8147e-08.
# Epoch: 1900, average train loss: 0.000000, average valid loss: 0.204876
# Epoch  1984: reducing learning rate of group 0 to 1.9073e-08.
# Epoch: 2000, average train loss: 0.000000, average valid loss: 0.204876
# Crop Name: 팥(국산)
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 02:09<00:00]
#     </div>
# Epoch:  100, average train loss: 0.084941, average valid loss: 0.170535
# Epoch:  200, average train loss: 0.007527, average valid loss: 0.027612
# Epoch:  300, average train loss: 0.005013, average valid loss: 0.022174
# Epoch   335: reducing learning rate of group 0 to 5.0000e-03.
# Epoch:  400, average train loss: 0.004591, average valid loss: 0.056884
# Epoch   436: reducing learning rate of group 0 to 2.5000e-03.
# Epoch:  500, average train loss: 0.004498, average valid loss: 0.086705
# Epoch   537: reducing learning rate of group 0 to 1.2500e-03.
# Epoch:  600, average train loss: 0.004303, average valid loss: 0.111740
# Epoch   638: reducing learning rate of group 0 to 6.2500e-04.
# Epoch:  700, average train loss: 0.003607, average valid loss: 0.129022
# Epoch   739: reducing learning rate of group 0 to 3.1250e-04.
# Epoch:  800, average train loss: 0.003483, average valid loss: 0.143875
# Epoch   840: reducing learning rate of group 0 to 1.5625e-04.
# Epoch:  900, average train loss: 0.003443, average valid loss: 0.146077
# Epoch   941: reducing learning rate of group 0 to 7.8125e-05.
# Epoch: 1000, average train loss: 0.003425, average valid loss: 0.146183
# Epoch  1042: reducing learning rate of group 0 to 3.9063e-05.
# Epoch: 1100, average train loss: 0.003417, average valid loss: 0.146140
# Epoch  1143: reducing learning rate of group 0 to 1.9531e-05.
# Epoch: 1200, average train loss: 0.003413, average valid loss: 0.146117
# Epoch  1244: reducing learning rate of group 0 to 9.7656e-06.
# Epoch: 1300, average train loss: 0.003411, average valid loss: 0.146109
# Epoch  1345: reducing learning rate of group 0 to 4.8828e-06.
# Epoch: 1400, average train loss: 0.003409, average valid loss: 0.146106
# Epoch  1446: reducing learning rate of group 0 to 2.4414e-06.
# Epoch: 1500, average train loss: 0.003409, average valid loss: 0.146107
# Epoch  1547: reducing learning rate of group 0 to 1.2207e-06.
# Epoch: 1600, average train loss: 0.003409, average valid loss: 0.146107
# Epoch  1648: reducing learning rate of group 0 to 6.1035e-07.
# Epoch: 1700, average train loss: 0.003408, average valid loss: 0.146107
# Epoch  1749: reducing learning rate of group 0 to 3.0518e-07.
# Epoch: 1800, average train loss: 0.003408, average valid loss: 0.146108
# Epoch  1850: reducing learning rate of group 0 to 1.5259e-07.
# Epoch: 1900, average train loss: 0.003408, average valid loss: 0.146108
# Epoch  1951: reducing learning rate of group 0 to 7.6294e-08.
# Epoch: 2000, average train loss: 0.003408, average valid loss: 0.146109
# Crop Name: 포도(캠벨)
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 02:09<00:00]
#     </div>
# Epoch:  100, average train loss: 0.051523, average valid loss: 0.045290
# Epoch:  200, average train loss: 0.011977, average valid loss: 0.012673
# Epoch   221: reducing learning rate of group 0 to 5.0000e-03.
# Epoch:  300, average train loss: 0.003476, average valid loss: 0.019529
# Epoch   322: reducing learning rate of group 0 to 2.5000e-03.
# Epoch:  400, average train loss: 0.001103, average valid loss: 0.023613
# Epoch   423: reducing learning rate of group 0 to 1.2500e-03.
# Epoch:  500, average train loss: 0.000687, average valid loss: 0.025631
# Epoch   524: reducing learning rate of group 0 to 6.2500e-04.
# Epoch:  600, average train loss: 0.000510, average valid loss: 0.026940
# Epoch   625: reducing learning rate of group 0 to 3.1250e-04.
# Epoch:  700, average train loss: 0.000432, average valid loss: 0.027539
# Epoch   726: reducing learning rate of group 0 to 1.5625e-04.
# Epoch:  800, average train loss: 0.000395, average valid loss: 0.027831
# Epoch   827: reducing learning rate of group 0 to 7.8125e-05.
# Epoch:  900, average train loss: 0.000376, average valid loss: 0.027980
# Epoch   928: reducing learning rate of group 0 to 3.9063e-05.
# Epoch: 1000, average train loss: 0.000366, average valid loss: 0.028059
# Epoch  1029: reducing learning rate of group 0 to 1.9531e-05.
# Epoch: 1100, average train loss: 0.000361, average valid loss: 0.028101
# Epoch  1130: reducing learning rate of group 0 to 9.7656e-06.
# Epoch: 1200, average train loss: 0.000358, average valid loss: 0.028124
# Epoch  1231: reducing learning rate of group 0 to 4.8828e-06.
# Epoch: 1300, average train loss: 0.000357, average valid loss: 0.028136
# Epoch  1332: reducing learning rate of group 0 to 2.4414e-06.
# Epoch: 1400, average train loss: 0.000356, average valid loss: 0.028142
# Epoch  1433: reducing learning rate of group 0 to 1.2207e-06.
# Epoch: 1500, average train loss: 0.000355, average valid loss: 0.028146
# Epoch  1534: reducing learning rate of group 0 to 6.1035e-07.
# Epoch: 1600, average train loss: 0.000355, average valid loss: 0.028147
# Epoch  1635: reducing learning rate of group 0 to 3.0518e-07.
# Epoch: 1700, average train loss: 0.000355, average valid loss: 0.028148
# Epoch  1736: reducing learning rate of group 0 to 1.5259e-07.
# Epoch: 1800, average train loss: 0.000355, average valid loss: 0.028149
# Epoch  1837: reducing learning rate of group 0 to 7.6294e-08.
# Epoch: 1900, average train loss: 0.000355, average valid loss: 0.028149
# Epoch  1938: reducing learning rate of group 0 to 3.8147e-08.
# Epoch: 2000, average train loss: 0.000355, average valid loss: 0.028149
# Crop Name: 풋고추
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 02:04<00:00]
#     </div>
# Epoch:  100, average train loss: 0.073762, average valid loss: 0.093223
# Epoch   168: reducing learning rate of group 0 to 5.0000e-03.
# Epoch:  200, average train loss: 0.009712, average valid loss: 0.190203
# Epoch   269: reducing learning rate of group 0 to 2.5000e-03.
# Epoch:  300, average train loss: 0.000229, average valid loss: 0.284228
# Epoch   370: reducing learning rate of group 0 to 1.2500e-03.
# Epoch:  400, average train loss: 0.000051, average valid loss: 0.292249
# Epoch   471: reducing learning rate of group 0 to 6.2500e-04.
# Epoch:  500, average train loss: 0.000024, average valid loss: 0.293780
# Epoch   572: reducing learning rate of group 0 to 3.1250e-04.
# Epoch:  600, average train loss: 0.000017, average valid loss: 0.294325
# Epoch   673: reducing learning rate of group 0 to 1.5625e-04.
# Epoch:  700, average train loss: 0.000014, average valid loss: 0.294556
# Epoch   774: reducing learning rate of group 0 to 7.8125e-05.
# Epoch:  800, average train loss: 0.000012, average valid loss: 0.294667
# Epoch   875: reducing learning rate of group 0 to 3.9063e-05.
# Epoch:  900, average train loss: 0.000012, average valid loss: 0.294723
# Epoch   976: reducing learning rate of group 0 to 1.9531e-05.
# Epoch: 1000, average train loss: 0.000011, average valid loss: 0.294752
# Epoch  1077: reducing learning rate of group 0 to 9.7656e-06.
# Epoch: 1100, average train loss: 0.000011, average valid loss: 0.294768
# Epoch  1178: reducing learning rate of group 0 to 4.8828e-06.
# Epoch: 1200, average train loss: 0.000011, average valid loss: 0.294776
# Epoch  1279: reducing learning rate of group 0 to 2.4414e-06.
# Epoch: 1300, average train loss: 0.000011, average valid loss: 0.294781
# Epoch  1380: reducing learning rate of group 0 to 1.2207e-06.
# Epoch: 1400, average train loss: 0.000011, average valid loss: 0.294783
# Epoch  1481: reducing learning rate of group 0 to 6.1035e-07.
# Epoch: 1500, average train loss: 0.000011, average valid loss: 0.294784
# Epoch  1582: reducing learning rate of group 0 to 3.0518e-07.
# Epoch: 1600, average train loss: 0.000011, average valid loss: 0.294785
# Epoch  1683: reducing learning rate of group 0 to 1.5259e-07.
# Epoch: 1700, average train loss: 0.000011, average valid loss: 0.294785
# Epoch  1784: reducing learning rate of group 0 to 7.6294e-08.
# Epoch: 1800, average train loss: 0.000011, average valid loss: 0.294785
# Epoch  1885: reducing learning rate of group 0 to 3.8147e-08.
# Epoch: 1900, average train loss: 0.000011, average valid loss: 0.294785
# Epoch  1986: reducing learning rate of group 0 to 1.9073e-08.
# Epoch: 2000, average train loss: 0.000011, average valid loss: 0.294785

# %%
def save_result_v2(model, data, crop_name, path):
    model.eval()
    X, y = sliding_windows(data, seq_length)
    X = torch.Tensor(np.array(X))
    y = torch.Tensor(np.array(y))
    y_preds = model(X).data.numpy()
    y_trues = y.data.numpy()
    
    
    for p_month in range(12):
        #print(data.shape)
        X, y = sliding_windows(data[-(seq_length+2):], seq_length)
        X = torch.Tensor(np.array(X))
        y = torch.Tensor(np.array(y))
        #print(X.shape, y.shape)

        y_pred = best_model(X).data.numpy()
        y_preds = np.append(y_preds, y_pred)
        y_true = y.data.numpy()
        #print(y_pred.shape)
        #print(y_pred)
        data = np.append(data, y_pred, axis=0)
        #print(y_pred.shape)
    
    plt.axvline(x=train_size, c='r', linestyle='--')
    plt.plot(y_trues, label='true', color='black', alpha=0.7)
    plt.plot(y_preds, label='pred', color='#5392cd')
    
    plt.show()
    return



fix_seed(SEED)

for i, crop in enumerate(progress_bar(crops)):
    print(f'Crop Name: {crop}')
    path = f'./results_test/{crop}'
    make_single_directory(path)
    
    # construct the data
    selected_data = scaler.fit_transform(df.iloc[:, i+1:i+2].values)
    X, y = sliding_windows(selected_data, seq_length)
    X = torch.Tensor(np.array(X))
    y = torch.Tensor(np.array(y))
    train_size = int(len(y) * 0.8)
    
    # load the model and infer
    best_model = torch.load(f'{path}/model_{crop}.pt')
    save_result_v2(best_model, selected_data, crop, path)
    break
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='32' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/32 00:00<00:00]
#     </div>
# Crop Name: 감자
